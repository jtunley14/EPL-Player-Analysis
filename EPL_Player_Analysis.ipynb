# %% [markdown]
# # Preliminary EDA
#
# 1. Creating dataframes for all premier league players.
# 2. Creating dataframes for all prem players by position and by team.
# <br> **More steps will be added later to explore positions besides strikers and teams besides Liverpool**
#
# 3. Darwin Nunez EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw = pd.read_csv('/Users/justintunley/Documents/WTW Analytics/epl_players_2023_2024.csv')

# %%
raw.shape
# Out:
# (455, 69)

# %%
raw.head()
# Out:
#    Unnamed: 0  season               player  fotmob_id     team         pos  \
# 0           1    2023           David Raya     562727  Arsenal      Keeper
# 1           2    2023       Aaron Ramsdale     746395  Arsenal      Keeper
# 2           3    2023  Oleksandr Zinchenko     623621  Arsenal   Left Back
# 3           4    2023    Takehiro Tomiyasu     664444  Arsenal  Right Back
# 4           5    2023            Ben White     776151  Arsenal  Right Back
#
#    height  weight age   foot  minutes  accurate_long_balls  accurate_passes  \
# 0  183 cm    80.0  28  Right      900             5.600000              NaN
# 1  188 cm    77.0  25  Right      450             3.400000              NaN
# 2  175 cm    61.0  26   Left      873             3.402062        68.865979
# 3  185 cm    70.0  25   Both      585             1.230769        51.384615
# 4  186 cm    72.0  26  Right     1051             2.654615        56.260704
#
# ...

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 455 entries, 0 to 454
# Data columns (total 69 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          455 non-null    int64
#  1   season                              455 non-null    int64
#  2   player                              455 non-null    object
#  3   fotmob_id                           455 non-null    int64
#  4   team                                455 non-null    object
#  5   pos                                 455 non-null    object
#  6   height                              455 non-null    object
#  7   weight                              452 non-null    float64
#  8   age                                 455 non-null    object
#  9   foot                                455 non-null    object
#  10  minutes                             455 non-null    int64
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
raw.head()
# Out:
#    Unnamed: 0  season               player  fotmob_id     team         pos  \
# 0           1    2023           David Raya     562727  Arsenal      Keeper
# 1           2    2023       Aaron Ramsdale     746395  Arsenal      Keeper
# 2           3    2023  Oleksandr Zinchenko     623621  Arsenal   Left Back
# 3           4    2023    Takehiro Tomiyasu     664444  Arsenal  Right Back
# 4           5    2023            Ben White     776151  Arsenal  Right Back
#
#    height  weight age   foot  minutes  accurate_long_balls  accurate_passes  \
# 0  183 cm    80.0  28  Right      900             5.600000              NaN
# 1  188 cm    77.0  25  Right      450             3.400000              NaN
# 2  175 cm    61.0  26   Left      873             3.402062        68.865979
# 3  185 cm    70.0  25   Both      585             1.230769        51.384615
# 4  186 cm    72.0  26  Right     1051             2.654615        56.260704
#
# ...

# %%
raw['season'].unique()
# only 2023 data. Good
# Out:
# array([2023])

# %%
raw['pos'] = raw['pos'].astype(str)
# set as string

# %% [markdown]
# # Making separate dataframes for positions
#
# Off rip we should focus on a position and player we want to focus on, like Nunez. But we could dive into any of these forever and get some good stuff out of it

# %%
liverpool = raw[raw['team'] == 'Liverpool']
liverpool.head()
# Out:
#     Unnamed: 0  season             player  fotmob_id       team          pos  \
# 22          23    2023     Alisson Becker     319784  Liverpool       Keeper
# 23          24    2023  Caoimhin Kelleher     776689  Liverpool       Keeper
# 24          25    2023         Joel Matip     171698  Liverpool  Center Back
# 25          26    2023    Virgil van Dijk     209405  Liverpool  Center Back
# 26          27    2023   Andrew Robertson     357880  Liverpool    Left Back
#
#     height  weight age   foot  minutes  accurate_long_balls  accurate_passes  \
# 22  193 cm    91.0  31  Right     1170             3.769231              NaN
# 23  188 cm    75.0  25  Right      180             3.000000              NaN
# 24  195 cm    89.0  32  Right      783             1.839080        56.781609
# 25  193 cm    92.0  32  Right     1108             4.954874        71.642599
# 26  178 cm    64.0  29   Left      720             2.125000        53.375000
#
# ...

# %%
strikers = raw[raw['pos'] == 'Striker']
strikers.head()
# Out:
#     Unnamed: 0  season          player  fotmob_id       team      pos  height  \
# 16          17    2023   Gabriel Jesus     576165    Arsenal  Striker  175 cm
# 18          19    2023     Kai Havertz     749736    Arsenal  Striker  193 cm
# 19          20    2023  Edward Nketiah     860920    Arsenal  Striker  175 cm
# 40          41    2023      Cody Gakpo     806552  Liverpool  Striker  193 cm
# 42          43    2023    Darwin Nunez     950561  Liverpool  Striker  185 cm
#
#     weight age   foot  minutes  accurate_long_balls  accurate_passes  \
# 16    73.0  26  Right      587             0.153322        22.385009
# 18    77.0  24   Both      828             0.326087        28.695652
# 19    72.0  24  Right      820                  NaN        13.829268
# 40    81.0  24  Right      589             0.305603        20.933786
# 42    81.0  24  Right      797             0.225847        16.712673
#
#     acted_as_sweeper  aerials_won  aerials_won_%  aerials_won_comp   assists  \
# ...

# %%
liverpool = liverpool.set_index(['player'])

# %%
liverpool = liverpool.drop(columns=('Unnamed: 0'))
liverpool.head()
# COMPARING DARWIN TO OTHERS ON HIS TEAM
# Out:
#                    season  fotmob_id       team          pos  height  weight  \
# player
# Alisson Becker       2023     319784  Liverpool       Keeper  193 cm    91.0
# Caoimhin Kelleher    2023     776689  Liverpool       Keeper  188 cm    75.0
# Joel Matip           2023     171698  Liverpool  Center Back  195 cm    89.0
# Virgil van Dijk      2023     209405  Liverpool  Center Back  193 cm    92.0
# Andrew Robertson     2023     357880  Liverpool    Left Back  178 cm    64.0
#
#                   age   foot  minutes  accurate_long_balls  accurate_passes  \
# player
# Alisson Becker     31  Right     1170             3.769231              NaN
# Caoimhin Kelleher  25  Right      180             3.000000              NaN
# Joel Matip         32  Right      783             1.839080        56.781609
# Virgil van Dijk    32  Right     1108             4.954874        71.642599
# Andrew Robertson   29   Left      720             2.125000        53.375000
#
# ...

# %%
liverpool['chances_created']
# Out:
# player
# Alisson Becker                 NaN
# Caoimhin Kelleher              NaN
# Joel Matip                0.229885
# Virgil van Dijk           0.487365
# Andrew Robertson          2.375000
# Joseph Gomez              1.019417
# Konstantinos Tsimikas     2.204900
# Trent Alexander-Arnold    2.400000
# Ibrahima Konaté           0.311958
# Jarell Quansah                 NaN
# Wataru Endo               0.290323
# Alexis Mac Allister       0.658135
# Dominik Szoboszlai        2.246490
# Curtis Jones                   NaN
# Ryan Gravenberch          1.136364
# Harvey Elliott            1.914894
# Mohamed Salah             2.436195
# Diogo Jota                1.687500
# Cody Gakpo                0.764007
# Luis Diaz                 1.075269
# Darwin Nunez              1.129235
# Name: chances_created, dtype: float64

# %%
strikers = strikers.set_index(['player'])

# %%
strikers = strikers.drop(columns=('Unnamed: 0'))
strikers.head()
# COMPARING DARWIN TO OTHER STRIKERS
# Out:
#                 season  fotmob_id       team      pos  height  weight age  \
# player
# Gabriel Jesus     2023     576165    Arsenal  Striker  175 cm    73.0  26
# Kai Havertz       2023     749736    Arsenal  Striker  193 cm    77.0  24
# Edward Nketiah    2023     860920    Arsenal  Striker  175 cm    72.0  24
# Cody Gakpo        2023     806552  Liverpool  Striker  193 cm    81.0  24
# Darwin Nunez      2023     950561  Liverpool  Striker  185 cm    81.0  24
#
#                  foot  minutes  accurate_long_balls  accurate_passes  \
# player
# Gabriel Jesus   Right      587             0.153322        22.385009
# Kai Havertz      Both      828             0.326087        28.695652
# Edward Nketiah  Right      820                  NaN        13.829268
# Cody Gakpo      Right      589             0.305603        20.933786
# Darwin Nunez    Right      797             0.225847        16.712673
#
#                 acted_as_sweeper  aerials_won  aerials_won_%  \
# player
# ...

# %%
S_columns_to_drop = ['clean_sheets_comp', 'clean_sheets', 'cross_accruracy', 'goals_conceded', 'goals_conceded_comp', 'goals_prevented', 'high_claims', 'keeper_high_claim_comp', 'keeper_sweeper_actions_comp', 'long_ball_succeeeded_accuracy_comp', 'save_percentage', 'save_percentage_comp', 'saves', 'successful_crosses']
# penalty goals conceded, penalties conceded, penalty_goals_conceded, penalty_goals_faced, penalty_goals_saves

# %%
strikers.head()
# Out:
#     Unnamed: 0  season          player  fotmob_id       team      pos  height  \
# 16          17    2023   Gabriel Jesus     576165    Arsenal  Striker  175 cm
# 18          19    2023     Kai Havertz     749736    Arsenal  Striker  193 cm
# 19          20    2023  Edward Nketiah     860920    Arsenal  Striker  175 cm
# 40          41    2023      Cody Gakpo     806552  Liverpool  Striker  193 cm
# 42          43    2023    Darwin Nunez     950561  Liverpool  Striker  185 cm
#
#     weight age   foot  minutes  accurate_long_balls  accurate_passes  \
# 16    73.0  26  Right      587             0.153322        22.385009
# 18    77.0  24   Both      828             0.326087        28.695652
# 19    72.0  24  Right      820                  NaN        13.829268
# 40    81.0  24  Right      589             0.305603        20.933786
# 42    81.0  24  Right      797             0.225847        16.712673
#
#     acted_as_sweeper  aerials_won  aerials_won_%  aerials_won_comp   assists  \
# ...

# %% [markdown]
# ### Keepers
# Not relevent rn

# %%
keepers = raw[raw['pos'] == 'Keeper']

# %%
keepers.head()
# Out:
#     Unnamed: 0  season             player  fotmob_id         team     pos  \
# 0            1    2023         David Raya     562727      Arsenal  Keeper
# 1            2    2023     Aaron Ramsdale     746395      Arsenal  Keeper
# 22          23    2023     Alisson Becker     319784    Liverpool  Keeper
# 23          24    2023  Caoimhin Kelleher     776689    Liverpool  Keeper
# 43          44    2023        Robin Olsen     120569  Aston Villa  Keeper
#
#     height  weight age   foot  minutes  accurate_long_balls  accurate_passes  \
# 0   183 cm    80.0  28  Right      900             5.600000              NaN
# 1   188 cm    77.0  25  Right      450             3.400000              NaN
# 22  193 cm    91.0  31  Right     1170             3.769231              NaN
# 23  188 cm    75.0  25  Right      180             3.000000              NaN
# 43  198 cm    89.0  33  Right       90             7.000000              NaN
#
# ...

# %% [markdown]
# ## Darwin Nunez

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows',None)

# %%
liverpool.isna().sum()
# Out:
# season                                 0
# fotmob_id                              0
# team                                   0
# pos                                    0
# height                                 0
# weight                                 1
# age                                    0
# foot                                   0
# minutes                                0
# accurate_long_balls                    0
# accurate_passes                        2
# acted_as_sweeper                      19
# aerials_won                            2
# aerials_won_%                          2
# aerials_won_comp                       2
# assists                                1
# blocked_scoring_attempt                6
# chances_created                        4
# chances_created_comp                   2
# clean_sheet_comp                      19
# clean_sheets                          19
# cross_accuracy                        13
# defensive_actions_comp                 2
# ...

# %%
liverpool.columns
# Out:
# Index(['season', 'fotmob_id', 'team', 'pos', 'height', 'weight', 'age', 'foot',
#        'minutes', 'accurate_long_balls', 'accurate_passes', 'acted_as_sweeper',
#        'aerials_won', 'aerials_won_%', 'aerials_won_comp', 'assists',
#        'blocked_scoring_attempt', 'chances_created', 'chances_created_comp',
#        'clean_sheet_comp', 'clean_sheets', 'cross_accuracy',
#        'defensive_actions_comp', 'dispossessed', 'dribbled_past', 'dribbles',
#        'dribbles_success_rate', 'duels_won', 'duels_won_%',
#        'error_led_to_goal', 'fouls_won', 'goals', 'goals_comp',
#        'goals_conceded', 'goals_conceded_comp', 'goals_prevented',
#        'high_claims', 'interceptions', 'keeper_high_claim_comp',
#        'keeper_sweeper_actions_comp', 'long_ball_accuracy',
#        'long_ball_succeeeded_accuracy_comp', 'pass_accuracy',
#        'penalties_awarded', 'penalties_conceded', 'penalty_goals',
#        'penalty_goals_conceded', 'penalty_goals_faced', 'penalty_goals_saves',
# ...
